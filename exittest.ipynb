# %% [markdown]
# # **MODEL FOR SELECTING FOOTBALL PLAYERS**
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Predict Player Performance by apply Machine Learning Model
# Done by: ALIYA P SUBEER
# The goal of the project aims to apply Data Science technologies and machine learning algorithms to predict player football performance by using "player_Attributes"

# %% [markdown]
# # **IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **UPLOAD DATASET**

# %%
from google.colab import drive
drive.mount('/content/drive')
data_train = pd.read_csv(r'/content/train (1).csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Save dataset to another variable**

# %%
data=data_train

# %%
data_train.head()
# Out:
#     player_id                 name  age gender    country height  weight  \
# 0   PLID_4964           Keva Horan   23      M    Ukraine    6'2  176lbs
# 1  PLID_11234           Herma Tann   18      M     Russia   5'10  148lbs
# 2  PLID_19127         Eilene Kizer   16      F      Spain    6'2  172lbs
# 3  PLID_17467       Andrea Badgett   27      M      Chile   5'11  165lbs
# 4   PLID_9661  Jeremiah Bumbalough   19      F  Argentina    5'8  158lbs
#
#    ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                     77.0           58.0          47.0  ...        Right
# 1                     54.0           69.0          70.0  ...          Any
# 2                     34.0           43.0          45.0  ...         Left
# 3                     79.0           73.0          76.0  ...        Right
# 4                     47.0           61.0          74.0  ...        Right
#
#    behaviour_rating  matches_played  fitness_rating  trophies_won  \
# 0               7.7             NaN             8.1           2.0
# 1               5.3             0.0             NaN           3.0
# 2               4.7             0.0             6.6           5.0
# 3               8.6           113.0             8.6           6.0
# 4               NaN             0.0             5.7           5.0
#
#    dedication_level     coaching  years_of_experience  \
# 0              High  Talent Hunt                  8.0
# 1            Medium       Source                  3.0
# 2               Low      Academy                  2.0
# 3            Medium      Academy                 13.0
# 4            Medium      Academy                  4.0
#
#    no_of_disqualifications  selection
# 0                      0.0          1
# 1                      0.0          0
# 2                      0.0          1
# 3                     16.0          1
# 4                      0.0          0
#
# [5 rows x 30 columns]

# %% [markdown]
# # **BASIC DATA DESCRIPTION**

# %% [markdown]
# **Show the number of rows and columns**

# %%
data_train.columns
# Out:
# Index(['player_id', 'name', 'age', 'gender', 'country', 'height', 'weight',
#        'ball_controlling_skills', 'body_reflexes', 'body_balance',
#        'jumping_skills', 'penalties_conversion_rate', 'mental_strength',
#        'goalkeeping_skills', 'defending_skills', 'passing_skills',
#        'dribbling_skills', 'shot_accuracy', 'body_strength_stamina',
#        'max_running_speed', 'strong_foot', 'behaviour_rating',
#        'matches_played', 'fitness_rating', 'trophies_won', 'dedication_level',
#        'coaching', 'years_of_experience', 'no_of_disqualifications',
#        'selection'],
#       dtype='object')

# %%
data_train.shape
# Out:
# (13994, 30)

# %%
data_train.describe()
# Out:
#                 age  ball_controlling_skills  body_reflexes  body_balance  \
# count  13994.000000             13581.000000   13994.000000  13994.000000
# mean      21.135844                56.043958      61.934329     62.753323
# std        5.162719                16.787353      14.931963     14.203638
# min       16.000000                 5.000000      12.000000      9.000000
# 25%       17.000000                51.000000      54.000000     55.000000
# 50%       20.000000                61.000000      64.000000     65.000000
# 75%       24.000000                67.000000      72.000000     73.000000
# max       61.000000                95.000000      96.000000     97.000000
#
#        jumping_skills  penalties_conversion_rate  mental_strength  \
# count    13970.000000               13964.000000     13966.000000
# mean        63.612026                  48.495703        56.768366
# std         11.938712                  15.767506        11.977744
# min         14.000000                   7.000000         9.000000
# 25%         57.000000                  39.000000        49.000000
# 50%         64.000000                  49.000000        58.000000
# 75%         72.000000                  60.000000        65.000000
# max         95.000000                  92.000000        92.000000
#
#        goalkeeping_skills  defending_skills  passing_skills  ...  \
# count        13994.000000      13994.000000    13994.000000  ...
# mean            16.474632         48.108118       52.935973  ...
# std             16.874551         16.821929       14.201782  ...
# min              1.000000          9.000000       13.000000  ...
# 25%             10.000000         36.000000       45.000000  ...
# 50%             11.000000         52.000000       56.000000  ...
# 75%             12.000000         61.000000       63.000000  ...
# max             88.000000         86.000000       89.000000  ...
#
#        shot_accuracy  body_strength_stamina  max_running_speed  \
# count   13422.000000           13994.000000       13994.000000
# mean       47.178140              62.652780          23.586094
# std        15.803991              11.512526           5.194387
# min         7.000000              15.000000           5.400000
# 25%        38.000000              56.000000          21.100000
# 50%        50.000000              64.000000          24.600000
# 75%        59.000000              71.000000          27.100000
# max        86.000000              92.000000          35.000000
#
#        behaviour_rating  matches_played  fitness_rating  trophies_won  \
# count      13291.000000    13328.000000    13299.000000  13994.000000
# mean           5.822068        3.908463        6.405482      3.389095
# std            1.095702       13.583229        1.706983      1.709152
# min            2.100000        0.000000        1.000000      0.000000
# 25%            5.100000        0.000000        5.600000      2.000000
# 50%            5.900000        0.000000        6.800000      3.000000
# 75%            6.500000        1.000000        7.500000      5.000000
# max            9.800000      151.000000       10.000000      9.000000
#
#        years_of_experience  no_of_disqualifications     selection
# count         13850.000000             13994.000000  13994.000000
# mean              6.434152                -4.740675      0.557525
# std               4.450954                72.023656      0.496698
# min               1.000000              -999.000000      0.000000
# 25%               2.000000                 0.000000      0.000000
# 50%               6.000000                 0.000000      1.000000
# 75%              10.000000                 0.000000      1.000000
# max              26.000000                25.000000      1.000000
#
# [8 rows x 21 columns]

# %% [markdown]
# ## **EDA**

# %%
corr = data_train.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_4eabf_row0_col0, #T_4eabf_row1_col1, #T_4eabf_row2_col2, #T_4eabf_row3_col3, #T_4eabf_row4_col4, #T_4eabf_row5_col5, #T_4eabf_row6_col6, #T_4eabf_row7_col7, #T_4eabf_row8_col8, #T_4eabf_row9_col9, #T_4eabf_row10_col10, #T_4eabf_row11_col11, #T_4eabf_row12_col12, #T_4eabf_row13_col13, #T_4eabf_row14_col14, #T_4eabf_row15_col15, #T_4eabf_row16_col16, #T_4eabf_row17_col17, #T_4eabf_row18_col18, #T_4eabf_row19_col19, #T_4eabf_row20_col20 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4eabf_row0_col1 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_4eabf_row0_col2, #T_4eabf_row19_col12 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_4eabf_row0_col3, #T_4eabf_row0_col13, #T_4eabf_row11_col18 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_4eabf_row0_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_4eabf_row0_col5, #T_4eabf_row14_col0, #T_4eabf_row18_col16 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_4eabf_row0_col6, #T_4eabf_row4_col10, #T_4eabf_row15_col5, #T_4eabf_row17_col16, #T_4eabf_row18_col11 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_4eabf_row0_col7, #T_4eabf_row0_col12, #T_4eabf_row4_col6 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_4eabf_row0_col8, #T_4eabf_row4_col9, #T_4eabf_row11_col14, #T_4eabf_row15_col8, #T_4eabf_row18_col1, #T_4eabf_row18_col7, #T_4eabf_row20_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_4eabf_row0_col9, #T_4eabf_row20_col8, #T_4eabf_row20_col13 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_4eabf_row0_col10, #T_4eabf_row15_col12 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_4eabf_row0_col11, #T_4eabf_row12_col4, #T_4eabf_row17_col13, #T_4eabf_row18_col8, #T_4eabf_row18_col9 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_4eabf_row0_col14, #T_4eabf_row14_col15 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_4eabf_row0_col15, #T_4eabf_row1_col15, #T_4eabf_row5_col15, #T_4eabf_row17_col4 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_4eabf_row0_col16, #T_4eabf_row15_col14, #T_4eabf_row17_col6, #T_4eabf_row17_col8 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_4eabf_row0_col17, #T_4eabf_row10_col15 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_4eabf_row0_col18, #T_4eabf_row2_col10, #T_4eabf_row18_col0 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_4eabf_row0_col19, #T_4eabf_row4_col19, #T_4eabf_row12_col19, #T_4eabf_row17_col19 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4eabf_row0_col20 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col0, #T_4eabf_row17_col14 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col2, #T_4eabf_row1_col13, #T_4eabf_row3_col13, #T_4eabf_row12_col8 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col3 {
#   background-color: #f59d7e;
#   color: #000000;
# }
# #T_4eabf_row1_col4, #T_4eabf_row6_col17, #T_4eabf_row11_col20, #T_4eabf_row17_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_4eabf_row1_col5 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col6, #T_4eabf_row9_col2, #T_4eabf_row13_col16 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col7, #T_4eabf_row2_col19, #T_4eabf_row3_col19, #T_4eabf_row5_col19, #T_4eabf_row7_col1, #T_4eabf_row7_col2, #T_4eabf_row7_col3, #T_4eabf_row7_col4, #T_4eabf_row7_col5, #T_4eabf_row7_col6, #T_4eabf_row7_col8, #T_4eabf_row7_col9, #T_4eabf_row7_col10, #T_4eabf_row7_col11, #T_4eabf_row7_col12, #T_4eabf_row7_col13, #T_4eabf_row7_col14, #T_4eabf_row7_col15, #T_4eabf_row7_col16, #T_4eabf_row7_col17, #T_4eabf_row10_col19, #T_4eabf_row11_col19, #T_4eabf_row13_col19, #T_4eabf_row16_col19, #T_4eabf_row18_col20, #T_4eabf_row20_col0, #T_4eabf_row20_col18 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col8 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_4eabf_row1_col9, #T_4eabf_row1_col11 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col10, #T_4eabf_row10_col1 {
#   background-color: #c12b30;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col12 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_4eabf_row1_col14, #T_4eabf_row4_col2, #T_4eabf_row20_col16 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_4eabf_row1_col16 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_4eabf_row1_col17, #T_4eabf_row1_col20, #T_4eabf_row19_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_4eabf_row1_col18, #T_4eabf_row8_col17, #T_4eabf_row11_col15, #T_4eabf_row20_col17 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_4eabf_row1_col19, #T_4eabf_row9_col19 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col0, #T_4eabf_row19_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col1 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col3 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col4, #T_4eabf_row10_col20 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_4eabf_row2_col5, #T_4eabf_row3_col11, #T_4eabf_row6_col16, #T_4eabf_row10_col6 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_4eabf_row2_col6, #T_4eabf_row4_col12 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_4eabf_row2_col7, #T_4eabf_row2_col18 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col8, #T_4eabf_row8_col5 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_4eabf_row2_col9 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col11, #T_4eabf_row9_col6, #T_4eabf_row16_col11 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col12, #T_4eabf_row3_col6, #T_4eabf_row8_col3, #T_4eabf_row14_col2 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_4eabf_row2_col13 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col14, #T_4eabf_row19_col3 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_4eabf_row2_col15, #T_4eabf_row13_col7 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_4eabf_row2_col16, #T_4eabf_row3_col9, #T_4eabf_row12_col1 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_4eabf_row2_col17, #T_4eabf_row12_col18 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_4eabf_row2_col20, #T_4eabf_row10_col4, #T_4eabf_row18_col3, #T_4eabf_row19_col6 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_4eabf_row3_col0, #T_4eabf_row5_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_4eabf_row3_col1, #T_4eabf_row9_col8, #T_4eabf_row10_col3, #T_4eabf_row11_col6, #T_4eabf_row13_col11 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_4eabf_row3_col2, #T_4eabf_row10_col2, #T_4eabf_row16_col1 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_4eabf_row3_col4, #T_4eabf_row18_col2, #T_4eabf_row19_col2 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_4eabf_row3_col5, #T_4eabf_row11_col12 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_4eabf_row3_col7 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_4eabf_row3_col8 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_4eabf_row3_col10, #T_4eabf_row9_col5, #T_4eabf_row16_col9 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_4eabf_row3_col12, #T_4eabf_row8_col14, #T_4eabf_row19_col1 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_4eabf_row3_col14 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_4eabf_row3_col15, #T_4eabf_row16_col7 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4eabf_row3_col16, #T_4eabf_row5_col6, #T_4eabf_row11_col3, #T_4eabf_row14_col1 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_4eabf_row3_col17 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_4eabf_row3_col18 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_4eabf_row3_col20, #T_4eabf_row5_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_4eabf_row4_col0, #T_4eabf_row13_col14, #T_4eabf_row15_col4 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_4eabf_row4_col1, #T_4eabf_row17_col9, #T_4eabf_row18_col6 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_4eabf_row4_col3, #T_4eabf_row18_c

# %% [markdown]
# highly correlated values are near to 1 and low  correlated values are clos to -1.passing_skills	dribbling_skills	shot_accuracy these all are highly correlated to selection.

# %%
rows=3
cols=3
fig,ax=plt.subplots(nrows=rows,ncols=cols,figsize=(10,10))
col=X.columns
index=0
for i in range(rows):
    for j in range(cols):
        sns.distplot(X[col[index]],ax=ax[i][j],kde_kws={'linewidth':3,"color":"red"})
        index=index+1
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
sns.pairplot(data_train, x_vars=['defending_skills','passing_skills','dribbling_skills'], y_vars='no_of_disqualifications', size=7, aspect=0.7)

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)
dataset_scaled = scaler.fit_transform(X)
X.hist(figsize = (16,16))
# Out:
# array([[<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'height'}>,
#         <Axes: title={'center': 'weight'}>,
#         <Axes: title={'center': 'ball_controlling_skills'}>,
#         <Axes: title={'center': 'body_reflexes'}>],
#        [<Axes: title={'center': 'body_balance'}>,
#         <Axes: title={'center': 'jumping_skills'}>,
#         <Axes: title={'center': 'penalties_conversion_rate'}>,
#         <Axes: title={'center': 'mental_strength'}>,
#         <Axes: title={'center': 'goalkeeping_skills'}>],
#        [<Axes: title={'center': 'defending_skills'}>,
#         <Axes: title={'center': 'passing_skills'}>,
#         <Axes: title={'center': 'dribbling_skills'}>,
#         <Axes: title={'center': 'shot_accuracy'}>,
#         <Axes: title={'center': 'body_strength_stamina'}>],
#        [<Axes: title={'center': 'max_running_speed'}>,
#         <Axes: title={'center': 'strong_foot'}>,
#         <Axes: title={'center': 'behaviour_rating'}>,
#         <Axes: title={'center': 'matches_played'}>,
#         <Axes: title={'center': 'fitness_rating'}>],
#        [<Axes: title={'center': 'trophies_won'}>,
#         <Axes: title={'center': 'dedication_level'}>,
#         <Axes: title={'center': 'coaching'}>,
#         <Axes: title={'center': 'years_of_experience'}>,
#         <Axes: title={'center': 'no_of_disqualifications'}>]],
#       dtype=object)

# %%
plt.hist(data_train.age, bins=100)
plt.xlabel("Age")
plt.ylabel("Number of players")
# Out:
# Text(0, 0.5, 'Number of players')

# %%
sns.boxplot(data["selection"])
pd.options.mode.chained_assignment = None

# %%
labelencoder = LabelEncoder()
data_train['strong_foot'].value_counts().plot(kind='pie')
labelencoder.fit(data_train['strong_foot'])
print(labelencoder.classes_)
# Out:
# ['Any' 'Left' 'None' 'Right' nan]

# %%
data_train["years_of_experience"].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='years_of_experience'>

# %%
sns.scatterplot(data=data_train, x="age", y="selection", hue="mental_strength")
# Out:
# <Axes: xlabel='age', ylabel='selection'>

# %%
ax = sns.kdeplot(data_train["selection"], shade=True)
sns.kdeplot(data_train["age"], shade=True)
# Out:
# <Axes: xlabel='selection', ylabel='Density'>

# %% [markdown]
# from the eda we can understand that more selection take place in average mental strength age between 25 to 40.most selected playesrs are right footed.2 years experience are more selected.

# %% [markdown]
# # **MISSING VALUE HANDLING AND OUTLIER DETECTION**

# %%
# Calculate the IQR
Q1 = data_train.quantile(0.25)
Q3 = data_train.quantile(0.75)
IQR = Q3 - Q1

# Define the upper and lower bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
data = data_train[~((data_train < lower_bound) | (data_train > upper_bound)).any(axis=1)]

# %%
data.boxplot(vert=False)

# Show the plot
plt.show()

# %%
data = data_train.dropna(axis=0)

# %%
duplicateDFRow = data[data.duplicated()] # check
print(duplicateDFRow)
# Out:
# Empty DataFrame
# Columns: [player_id, name, age, gender, country, height, weight, ball_controlling_skills, body_reflexes, body_balance, jumping_skills, penalties_conversion_rate, mental_strength, goalkeeping_skills, defending_skills, passing_skills, dribbling_skills, shot_accuracy, body_strength_stamina, max_running_speed, strong_foot, behaviour_rating, matches_played, fitness_rating, trophies_won, dedication_level, coaching, years_of_experience, no_of_disqualifications, selection]
# Index: []
#
# [0 rows x 30 columns]

# %%
data = data.drop_duplicates() # Drop it
data.shape
# Out:
# (10171, 30)

# %%
data_train.dtypes
# Out:
# player_id                     object
# name                          object
# age                            int64
# gender                        object
# country                       object
# height                         int64
# weight                         int64
# ball_controlling_skills      float64
# body_reflexes                float64
# body_balance                 float64
# jumping_skills               float64
# penalties_conversion_rate    float64
# mental_strength              float64
# goalkeeping_skills           float64
# defending_skills             float64
# passing_skills               float64
# dribbling_skills             float64
# shot_accuracy                float64
# body_strength_stamina        float64
# max_running_speed            float64
# strong_foot                    int64
# behaviour_rating             float64
# matches_played               float64
# fitness_rating               float64
# trophies_won                 float64
# dedication_level               int64
# coaching                       int64
# years_of_experience          float64
# no_of_disqualifications      float64
# selection                      int64
# dtype: object

# %%
data=data_train

# %%
data['height'].value_counts()
data['weight'].value_counts()
data['strong_foot'].value_counts()
data['dedication_level'].value_counts()
data['coaching'].value_counts()
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
data['height'] = labelencoder.fit_transform(data['height'])
data['weight'] = labelencoder.fit_transform(data['weight'])
data['strong_foot'] = labelencoder.fit_transform(data['strong_foot'])
data['dedication_level']= labelencoder.fit_transform(data['dedication_level'])
data['coaching']= labelencoder.fit_transform(data['coaching'])
data
# Out:
#         player_id                 name  age gender    country  height  weight  \
# 0       PLID_4964           Keva Horan   23      M    Ukraine      18      47
# 1      PLID_11234           Herma Tann   18      M     Russia       5      24
# 2      PLID_19127         Eilene Kizer   16      F      Spain      18      44
# 3      PLID_17467       Andrea Badgett   27      M      Chile       6      38
# 4       PLID_9661  Jeremiah Bumbalough   19      F  Argentina      13      32
# ...           ...                  ...  ...    ...        ...     ...     ...
# 13989  PLID_10956         Viva Stepney   20      M    Uruguay      15      35
# 13990  PLID_17290           Illa Pitre   18      F    England       5      38
# 13991   PLID_5193    Marylouise Mosley   17      M      Japan      15      44
# 13992  PLID_12173       Teri Escamilla   20      F    Ukraine       5      26
# 13993    PLID_236       Darius Schuman   16      F      Chile      13      33
#
#        ball_controlling_skills  body_reflexes  body_balance  ...  strong_foot  \
# 0                         77.0           58.0          47.0  ...            3
# 1                         54.0           69.0          70.0  ...            0
# 2                         34.0           43.0          45.0  ...            1
# 3                         79.0           73.0          76.0  ...            3
# 4                         47.0           61.0          74.0  ...            3
# ...                        ...            ...           ...  ...          ...
# 13989                     60.0           48.0          62.0  ...            3
# 13990                     53.0           68.0          59.0  ...            3
# 13991                     56.0           73.0          62.0  ...            1
# 13992                     71.0           69.0          70.0  ...            1
# 13993                     53.0           59.0          67.0  ...            3
#
#        behaviour_rating  matches_played  fitness_rating  trophies_won  \
# 0                   7.7             NaN             8.1           2.0
# 1                   5.3             0.0             NaN           3.0
# 2                   4.7             0.0             6.6           5.0
# 3                   8.6           113.0             8.6           6.0
# 4                   NaN             0.0             5.7           5.0
# ...                 ...             ...             ...           ...
# 13989               6.0             NaN             7.6           2.0
# 13990               5.3             0.0             5.6           3.0
# 13991               5.7             0.0             7.7           3.0
# 13992               6.8             1.0             5.8           4.0
# 13993               4.2             0.0             6.7           0.0
#
#        dedication_level  coaching  years_of_experience  \
# 0                     0         2                  8.0
# 1                     2         1                  3.0
# 2                     1         0                  2.0
# 3                     2         0                 13.0
# 4                     2         0                  4.0
# ...                 ...       ...                  ...
# 13989                 2         0                  6.0
# 13990                 2         0                  4.0
# 13991                 1         2                  2.0
# 13992                 2         0                  6.0
# 13993                 2         1                  1.0
#
#        no_of_disqualifications  selection
# 0                          0.0          1
# 1                          0.0          0
# 2                          0.0          1
# 3                         16.0          1
# 4                          0.0          0
# ...                        ...        ...
# 13989                      0.0          1
# 13990                      0.0          0
# 13991                      0.0          1
# 13992                      0.0          1
# 13993                      0.0          0
#
# [13994 rows x 30 columns]

# %%
data.isna().sum()
# Out:
# player_id                      0
# name                           0
# age                            0
# gender                        19
# country                        0
# height                         0
# weight                         0
# ball_controlling_skills      413
# body_reflexes                  0
# body_balance                   0
# jumping_skills                24
# penalties_conversion_rate     30
# mental_strength               28
# goalkeeping_skills             0
# defending_skills               0
# passing_skills                 0
# dribbling_skills               0
# shot_accuracy                572
# body_strength_stamina          0
# max_running_speed              0
# strong_foot                    0
# behaviour_rating             703
# matches_played               666
# fitness_rating               695
# trophies_won                   0
# dedication_level               0
# coaching                       0
# years_of_experience          144
# no_of_disqualifications        0
# selection                      0
# dtype: int64

# %%
data.dropna(how='all', inplace=True)

# %%
X = data.drop(['player_id', 'name', 'gender', 'country'],axis=1)
Y=data['selection']
print('Shape of X:  ',X.shape , ' sahpe of y:   ',Y.shape)
# Out:
# Shape of X:   (13994, 26)  sahpe of y:    (13994,)

# %%
X.dropna(inplace=True)

# %%
#Use a features selection technique to select those features in
#your data that contribute most to the prediction.
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,Y)
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(15).plot(kind='barh')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-223-d8ec694664e4> in <cell line: 6>()
#       4 import matplotlib.pyplot as plt
#       5 model = ExtraTreesClassifier()
# ----> 6 model.fit(X,Y)
#       7 print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
#       8 #plot graph of feature importances for better visualization
#
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     343         if issparse(y):
#     344             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345         X, y = self._validate_data(
#     346             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347         )
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1122     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1123
# -> 1124     check_consistent_length(X, y)
#    1125
#    1126     return X, y
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     395     uniques = np.unique(lengths)
#     396     if len(uniques) > 1:
# --> 397         raise ValueError(
#     398             "Found input variables with inconsistent numbers of samples: %r"
#     399             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [11013, 13994]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print('shape of X_train:',X_train.shape,'shape of X_test:',X_test.shape,'shape of y_train:',Y_train.shape,'shape of y_test:',Y_test.shape )
# Out:
# shape of X_train: (8798, 25) shape of X_test: (2200, 25) shape of y_train: (8798,) shape of y_test: (2200,)

# %%
from sklearn.linear_model import LinearRegression
linear = LinearRegression()
linear.fit(X_train,Y_train)
pred = linear.predict(X_test)
accuracy_score_LR= linear.score(X_test,Y_test)
accuracy_score_LR
# Out:
# 0.34365505540144803

# %%
print(linear.intercept_)
print(linear.coef_)
# Out:
# -1.2198517281775967
# [-1.03446717e-03  2.38143360e-03  6.61149694e-04  1.01966015e-02
#  -7.38482901e-04 -7.17478338e-04  1.75856136e-03  2.02234608e-03
#   7.74422317e-03  1.31788882e-02  5.71576996e-03 -1.81486146e-03
#   1.11287682e-03  6.91111989e-04  6.48296968e-04 -1.00947525e-03
#  -2.47115401e-03  1.23942672e-01  1.64801314e-03 -3.35770881e-02
#   2.73378072e-03 -1.43712255e-02  2.72326714e-03 -5.58840150e-02
#   4.04607067e-05]

# %%
from sklearn import metrics
print(metrics.mean_absolute_error(Y_test,pred))
# Out:
# 0.345227583651115

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
pipeline = make_pipeline(PolynomialFeatures(2), LinearRegression())

# %%
pipeline.fit(np.array(X_train), Y_train)
y_pred=pipeline.predict(X_test)

# %%
accuracy_score = pipeline.score(X_train,Y_train)
print('Model Accuracy: ', accuracy_score)
# Out:
# Model Accuracy:  0.5185971561804543

# %%
from sklearn.linear_model import LogisticRegression
# Create a logistic regression model
log_model = LogisticRegression()

# Train the model on the training data
log_model.fit(X_train, Y_train)

# Make predictions on the test data
y_pred = model.predict(X_test)

# Evaluate the model's performance
accuracy = model.score(X_test, Y_test)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.8354545454545454

# %%
from sklearn.preprocessing import MinMaxScaler

# Scale the data to a range where all values are non-negative
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Apply SelectKBest with chi2 scoring function
selector = SelectKBest(chi2, k=5)
X_new = selector.fit_transform(X_scaled, Y)

# Display the selected features
selected_features = X.columns[selector.get_support()]
print('Selected features:', selected_features)
# Out:
# Selected features: Index(['ball_controlling_skills', 'passing_skills', 'behaviour_rating',
#        'matches_played', 'years_of_experience'],
#       dtype='object')

# %%
from sklearn.tree import DecisionTreeClassifier

# Create a decision tree classifier
decision_model = DecisionTreeClassifier()

# Train the model on the training data
decision_model.fit(X_train, Y_train)

# Make predictions on the test data
y_pred = decision_model.predict(X_test)

# Evaluate the model's performance
accuracy1 = decision_model.score(X_test, Y_test)
print('Accuracy:', accuracy1)
# Out:
# Accuracy: 0.7945454545454546

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split


# Split the data into training and test sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# Create a random forest classifier
random_model = RandomForestClassifier()

# Train the model on the training data
random_model.fit(X_train, Y_train)

# Make predictions on the test data
y_pred = random_model.predict(X_test)

# Evaluate the model's performance
accuracy2 = random_model.score(X_test, Y_test)
print('Accuracy:', accuracy2)
# Out:
# Accuracy: 0.8454545454545455

# %%
pipeline = make_pipeline(PolynomialFeatures(2), RandomForestClassifier())
pipeline.fit(np.array(X_train), Y_train)
y_pred=pipeline.predict(X_test)
accuracy_score_RFPIPELINE = pipeline.score(X_train,Y_train)
print('Model Accuracy: ', accuracy_score_RFPIPELINE)
# Out:
# Model Accuracy:  1.0

# %%
import pandas as pd
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split


# Create a gradient boosting classifier
grad_model = GradientBoostingClassifier()

# Train the model on the training data
grad_model.fit(X_train, Y_train)

# Make predictions on the test data
y_pred = grad_model.predict(X_test)

# Evaluate the model's performance
accuracy3 = grad_model.score(X_test, Y_test)
print('Accuracy:', accuracy3)
# Out:
# Accuracy: 0.8504545454545455

# %%
row_names = ['Algorithm', 'Accuracy']
alg = ["LINEAR", "LOGISTICC", "RANDOMFOREST", "DECISIONTREE", "GRADIENTBOOSTIONG",'RANDOMFORESTPIPELINING']
comp = [accuracy_score_LR,accuracy, accuracy2, accuracy1, accuracy3,accuracy_score_RFPIPELINE]
d = {}
for i in range(0, 6):
    d[i] = [alg[i], comp[i]]
table = pd.DataFrame(d, index=row_names)
print(table)
# Out:
#                   0          1             2             3                  4  \
# Algorithm    LINEAR  LOGISTICC  RANDOMFOREST  DECISIONTREE  GRADIENTBOOSTIONG
# Accuracy   0.343655   0.868636      0.845455      0.794545           0.850455
#
#                                 5
# Algorithm  RANDOMFORESTPIPELINING
# Accuracy                      1.0
